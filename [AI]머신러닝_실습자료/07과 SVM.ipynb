# %% [markdown]
# # SVM

# %% [markdown]
# ## 1.SVM 개념이해

# %% [markdown]
# ### (1) import

# %%
#라이브러리들을 불러오자.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.datasets import make_moons, make_classification

from sklearn.svm import SVC

import warnings    # 경고메시지 제외
warnings.filterwarnings(action='ignore')

# %% [markdown]
# ### (2) 함수 생성

# %% [markdown]
# * svm 모델을 시각화 하는 함수를 생성해 봅시다.

# %%
def svm_visualize(x, y, model, title = "") :

    xx, yy = np.meshgrid(np.linspace(x[:,0].min(), x[:,0].max(), 50), 
                         np.linspace(x[:,1].min(), x[:,1].max(), 50)) # mesh grid

    # 메쉬 그리드값에 대해 모델 부터 거리 값 만들기.
    Z = model.decision_function(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)

    # 그래프 그리기
    plt.figure(figsize=(6, 6))
    # 데이터 산점도
    sns.scatterplot(x=x[:,0], y=x[:,1], hue=y)
    # levels= 0 모델 ,  -1, 1 은 마진 경계
    plt.contour(xx, yy, Z, levels=[-1, 0, 1], colors = 'gray',linestyles  = ['--','-','--'])
    plt.title(title)
    plt.axis("tight")
    plt.show()

# %% [markdown]
# ### (3) 샘플데이터 생성

# %%
seed = 8

x, y = make_classification(n_samples=100,
                        n_features=2, 
                        n_redundant=0, 
                        weights = [0.5, 0.5],  # class 0과 1의 비율 조정 ==> class imbalance 상황만들기
                        n_clusters_per_class=1, 
                        random_state=seed)
sns.scatterplot(x[:,0], x[:,1], hue = y)
plt.show()

# %% [markdown]
# ### (4) SVM 모델 생성 및 시각화

# %%
model = SVC(kernel = 'linear', C = 10)
model.fit(x,y)
svm_visualize(x, y, model)

# %% [markdown]
# ### (5) 결정 경계와 마진

# %% [markdown]
# * 새로운 샘플 데이터를 다시 생성해 봅시다.

# %%
seed = 34
x, y = make_classification(n_features=2, n_redundant=0, weights = [0.5, 0.5],
                        n_clusters_per_class=1, random_state=seed)

# %% [markdown]
# * cost 값을 0.1, ~ 20 사이의 숫자로 변경하며 cost에 따른 모델을 살펴 봅시다.

# %%
cost = 40
model = SVC(kernel = 'linear', C = cost)
model.fit(x,y)
svm_visualize(x, y, model, cost)

# %% [markdown]
# ### (6) 선형경계로 분류할 수 없는 데이터셋

# %% [markdown]
# * 데이터를 생성하고 시각화 해 봅시다.

# %%
x, y = make_moons(n_samples = 200, noise = .13, random_state = 10)

plt.figure(figsize = (6,6))
sns.scatterplot(x[:,0], x[:,1], hue = y)
plt.show()

# %% [markdown]
# * 선형경계로 분류

# %%
model = SVC(kernel = 'linear')
model.fit(x,y)
svm_visualize(x, y, model)

# %% [markdown]
# * 커널 트릭 사용 : rbf

# %%
model = SVC(kernel = 'rbf', C = 1)
model.fit(x,y)
svm_visualize(x, y, model)

# %% [markdown]
# ### (7) 하이퍼파라미터

# %% [markdown]
# * Cost :
#     * 오류를 허용하지 않으려는 비용(노력!)
#     * 값이 클수록 오류를 허용하지 않기 위한 경계를 만들려고 함.
# * gamma :
#     * 결정경계의 곡률
#     * 값이 클수록 곡률반경이 작아짐.

# %% [markdown]
# * Cost에 따라 결정 경계가 어떻게 달라지는지 살펴 봅시다.

# %%
for cost in [0.1, .5, 2, 20] : 
    model = SVC(kernel = 'rbf', C = cost)
    model.fit(x,y)
    svm_visualize(x, y, model, cost)

# %% [markdown]
# * gamma에 따라 결정 경계가 어떻게 달라지는지 살펴 봅시다.

# %%
for g in [.5, 1, 5, 10] : 
    model = SVC(kernel = 'rbf', C = 2, gamma =  g)
    model.fit(x,y)
    svm_visualize(x, y, model, g)

# %% [markdown]
# ## 2.데이터 준비

# %% [markdown]
# * 변수설명
#     * COLLEGE : 대학 졸업여부
#     * INCOME : 연수입
#     * OVERAGE : 월평균 초과사용 시간(분)
#     * LEFTOVER : 월평균 잔여시간비율(%)
#     * HOUSE : 집값
#     * HANDSET_PRICE : 스마트폰 가격
#     * OVER_15MINS_CALLS_PER_MONTH : 월평균 장기통화(15분이상) 횟수
#     * AVERAGE_CALL_DURATION : 평균 통화 시간
#     * REPORTED_SATISFACTION : 만족도 설문조사 결과
#     * REPORTED_USAGE_LEVEL : 사용도 자가진단 결과
#     * CONSIDERING_CHANGE_OF_PLAN : 향후 변경계획 설문조사 결과
#     * CHURN : 이탈(번호이동) 여부 (Target 변수)

# %%
# 데이터를 불러옵시다.
path = 'https://raw.githubusercontent.com/DA4BAM/dataset/master/mobile_cust_churn.csv'
data = pd.read_csv(path)
data = data.sample(5000, random_state = 2022)

# %% [markdown]
# ### (1) 데이터 정리

# %%
drop_cols = ['id']
data.drop(drop_cols, axis = 1, inplace = True )

# %% [markdown]
# ### (2) 데이터분할1 : x, y 나누기

# %%
target = 'CHURN'
x = data.drop(target, axis = 1)
y = data.loc[:, target]

# %% [markdown]
# ### (3) NA 조치

# %% [markdown]
# ### (4) 가변수화

# %%
dumm_cols = ['REPORTED_SATISFACTION','REPORTED_USAGE_LEVEL','CONSIDERING_CHANGE_OF_PLAN']
x = pd.get_dummies(x, columns = dumm_cols, drop_first = True)

# %% [markdown]
# ### (5) 데이터분할2 : train : validation 나누기

# %%
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size = .3, random_state = 2022)

# %% [markdown]
# ### (6) Scaling

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train)
x_val = scaler.transform(x_val)

# %% [markdown]
# ## 3.모델링

# %% [markdown]
# ### (1) 필요한 함수 불러오기
#
# * SVM
#     * SVC : 분류
#     * SVR : 회귀

# %%
# 모델링을 위해
from sklearn.svm import SVC

# 평가를 위해.
from sklearn.metrics import *

# %% [markdown]
# ### (2) 선언

# %%
model = SVC()

# %% [markdown]
# ### (3) 모델링(학습)

# %%
model.fit(x_train, y_train)
# Out:
# SVC()

# %% [markdown]
# ### (4) 검증 : 예측

# %%
pred = model.predict(x_val)

# %% [markdown]
# ### (5) 검증 : 평가

# %% [markdown]
# * confusion matrix

# %%
confusion_matrix(y_val, pred)
# Out:
# array([[436, 295],
#        [204, 565]], dtype=int64)

# %% [markdown]
# * classification report

# %%
print(classification_report(y_val, pred))
# Out:
#               precision    recall  f1-score   support
#
#        LEAVE       0.68      0.60      0.64       731
#         STAY       0.66      0.73      0.69       769
#
#     accuracy                           0.67      1500
#    macro avg       0.67      0.67      0.66      1500
# weighted avg       0.67      0.67      0.67      1500

# %% [markdown]
# ## 4.실습 : C와 gamma를 조절하며 모델링 하기

# %%
scores = []
for c in [.1, .5, 1, 5, 10, 15, 20, 50, 100]:
    model = SVC(C=c)
    model.fit(x_train, y_train)
    pred = model.predict(x_val)
    print(confusion_matrix(y_val, pred))
    print(classification_report(y_val, pred))
    scores.append((accuracy_score(y_val, pred), c))
    print('-' * 20)
# Out:
# [[377 354]
#  [177 592]]
#               precision    recall  f1-score   support
#
#        LEAVE       0.68      0.52      0.59       731
#         STAY       0.63      0.77      0.69       769
#
#     accuracy                           0.65      1500
#    macro avg       0.65      0.64      0.64      1500
# weighted avg       0.65      0.65      0.64      1500
#
# --------------------
# [[422 309]
#  [193 576]]
#               precision    recall  f1-score   support
#
#        LEAVE       0.69      0.58      0.63       731
#         STAY       0.65      0.75      0.70       769
#
#     accuracy                           0.67      1500
#    macro avg       0.67      0.66      0.66      1500
# weighted avg       0.67      0.67      0.66      1500
#
# --------------------
# [[436 295]
#  [204 565]]
#               precision    recall  f1-score   support
#
#        LEAVE       0.68      0.60      0.64       731
#         STAY       0.66      0.73      0.69       769
#
#     accuracy                           0.67      1500
#    macro avg       0.67      0.67      0.66      1500
# weighted avg       0.67      0.67      0.67      1500
#
# --------------------
# [[440 291]
#  [252 517]]
#               precision    recall  f1-score   support
#
#        LEAVE       0.64      0.60      0.62       731
#         STAY       0.64      0.67      0.66       769
#
#     accuracy                           0.64      1500
#    macro avg       0.64      0.64      0.64      1500
# weighted avg       0.64      0.64      0.64      1500
#
# --------------------
# [[433 298]
#  [250 519]]
#               precision    recall  f1-score   support
#
#        LEAVE       0.63      0.59      0.61       731
#         STAY       0.64      0.67      0.65       769
#
#     accuracy                           0.63      1500
#    macro avg       0.63      0.63      0.63      1500
# weighted avg       0.63      0.63      0.63      1500
#
# --------------------
# [[433 298]
#  [247 522]]
#               precision    recall  f1-score   support
#
#        LEAVE       0.64      0.59      0.61       731
#         STAY       0.64      0.68      0.66       769
#
#     accuracy                           0.64      1500
#    macro avg       0.64      0.64      0.64      1500
# weighted avg       0.64      0.64      0.64      1500
#
# --------------------
# [[434 297]
#  [256 513]]
#               precision    recall  f1-score   support
#
#        LEAVE       0.63      0.59      0.61       731
#         STAY       0.63      0.67      0.65       769
#
#     accuracy                           0.63      1500
#    macro avg       0.63      0.63      0.63      1500
# weighted avg       0.63      0.63      0.63      1500
#
# --------------------
# [[422 309]
#  [272 497]]
#               precision    recall  f1-score   support
#
#        LEAVE       0.61      0.58      0.59       731
#         STAY       0.62      0.65      0.63       769
#
#     accuracy                           0.61      1500
#    macro avg       0.61      0.61      0.61      1500
# weighted avg       0.61      0.61      0.61      1500
#
# --------------------
# [[424 307]
#  [278 491]]
#               precision    recall  f1-score   support
#
#        LEAVE       0.60      0.58      0.59       731
#         STAY       0.62      0.64      0.63       769
#
#     accuracy                           0.61      1500
#    macro avg       0.61      0.61      0.61      1500
# weighted avg       0.61      0.61      0.61      1500
#
# --------------------

# %%
scores
# Out:
# [(0.646, 0.1),
#  (0.6653333333333333, 0.5),
#  (0.6673333333333333, 1),
#  (0.638, 5),
#  (0.6346666666666667, 10),
#  (0.6366666666666667, 15),
#  (0.6313333333333333, 20),
#  (0.6126666666666667, 50),
#  (0.61, 100)]

# %%
max(scores)
# Out:
# (0.6673333333333333, 1)

# %%
plt.figure(figsize=(10, 8))
plt.plot([i[1] for i in scores], [i[0] for i in scores])
plt.xlabel('Cost')
plt.ylabel('acc')
plt.show()
