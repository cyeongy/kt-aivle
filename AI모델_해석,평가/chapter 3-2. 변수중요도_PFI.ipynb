# %% [markdown]
# # 모델에 대한 설명1_PFI
# * Permutation Feature Importance

# %% [markdown]
# ## 1.환경준비

# %% [markdown]
# ### 1) 라이브러리 로딩

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.simplefilter(action='ignore')

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC, SVR
from sklearn.neighbors import KNeighborsRegressor, KNeighborsClassifier
from sklearn.metrics import * 

import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense
from keras.backend import clear_session

# %% [markdown]
# ### 2) 데이터 로딩

# %%
data = pd.read_csv('https://raw.githubusercontent.com/DA4BAM/dataset/master/boston.csv')
data.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#     black  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %% [markdown]
# * 변수 설명
#     * crim : 범죄율
#     * zn : 대저택 비율
#     * indus : 산업단지 비율
#     * chas : 찰스 강변 여부
#     * nox : 일산화질소 농도(공기오염도)
#     * rm : 평균 주택당 방 수
#     * age : 30년 이상된 주택 비율
#     * dis : 주요 업무 지역 접근성 지수
#     * rad : 고속도로 접근성 지수
#     * tax  1만 달러당 재산세
#     * ptratio : 교사 1명당 학생수
#     * lstat : 하위계층 비율
#     * black : 흑인비율(원래 숫자를 변형한 것임)
#     * mdev : 타운별 집값 중위수(단위 : 1000달러)

# %% [markdown]
# ### 3) 필요한 함수 생성

# %%
# 변수 중요도 plot
def plot_feature_importance(importance, names, topn = 'all'):
    feature_importance = np.array(importance)
    feature_names = np.array(names)

    data={'feature_names':feature_names,'feature_importance':feature_importance}
    fi_temp = pd.DataFrame(data)

    fi_temp.sort_values(by=['feature_importance'], ascending=False,inplace=True)
    fi_temp.reset_index(drop=True, inplace = True)

    if topn == 'all' :
        fi_df = fi_temp.copy()
    else :
        fi_df = fi_temp.iloc[:topn]

    plt.figure(figsize=(10,8))
    sns.barplot(x='feature_importance', y='feature_names', data = fi_df)

    plt.xlabel('importance')
    plt.ylabel('feature names')
    plt.grid()

    return fi_df

# %% [markdown]
# ## 2.데이터 준비

# %% [markdown]
# ### 1) x, y로 나누기

# %%
target = 'medv'
x = data.drop(target, axis = 1)
y = data.loc[:,target]

# %% [markdown]
# ### 2) 가변수화

# %% [markdown]
# ### 3) train : validation 분할

# %%
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size = .2, random_state = 2022)
x_train.shape
# Out:
# (404, 13)

# %% [markdown]
# ### 4) 스케일링

# %%
scaler = MinMaxScaler()
x_train_s = scaler.fit_transform(x_train)
x_val_s = scaler.transform(x_val)

# %% [markdown]
# ## 3.Permutation Feature Importance
#
# * model1 : SVM
# * model2 : DL

# %%
from sklearn.inspection import permutation_importance

# %% [markdown]
# ### 1) SVM 모델

# %%
model1 = SVR()
model1.fit(x_train_s, y_train)
# Out:
# SVR()

# %% [markdown]
# * permutation feature importance 구하기

# %%
pfi1 = permutation_importance(model1, x_val_s, y_val, n_repeats=10, scoring = 'r2', random_state=2022)

# %%
pfi1
# Out:
# {'importances_mean': array([0.00945374, 0.02086725, 0.03294957, 0.03386631, 0.02895424,
#         0.14430705, 0.05740539, 0.01810863, 0.02795648, 0.06606279,
#         0.07908538, 0.01881995, 0.24118307]),
#  'importances_std': array([0.00267741, 0.00728268, 0.00678155, 0.01320997, 0.00993524,
#         0.01427471, 0.01680534, 0.01403577, 0.01069404, 0.01817568,
#         0.01402084, 0.01418209, 0.02658648]),
#  'importances': array([[0.01202894, 0.0107116 , 0.00956138, 0.01383913, 0.00721868,
#          0.00671367, 0.0131682 , 0.00643447, 0.00687128, 0.00799003],
#         [0.01532828, 0.02365336, 0.031247  , 0.01905323, 0.03024437,
#          0.01534974, 0.02420276, 0.0057787 , 0.01862319, 0.02519188],
#         [0.01920832, 0.03288757, 0.03588737, 0.03716216, 0.03562646,
#          0.03493756, 0.03327672, 0.02338953, 0.0322704 , 0.04484963],
#         [0.04604279, 0.02896597, 0.02650305, 0.06144869, 0.03828285,
#          0.02357206, 0.03553383, 0.00886427, 0.03593179, 0.03351783],
#         [0.02155195, 0.02763862, 0.02381862, 0.04908277, 0.04350943,
#          0.01898032, 0.0253759 , 0.0174404 , 0.03515601, 0.02698836],
#         [0.14934697, 0.14898562, 0.13328107, 0.13896236, 0.12637877,
#          0.16767923, 0.16166089, 0.15589054, 0.12170238, 0.13918266],
#         [0.04145372, 0.06286162, 0.07553061, 0.08115248, 0.05905493,
#          0.03770048, 0.05865293, 0.02669361, 0.07500178, 0.05595176],
#         [0.00577686, 0.0067193 , 0.01801397, 0.02357895, 0.05238462,
#          0.00363296, 0.00710871, 0.02852383, 0.02236743, 0.01297963],
#         [0.01190827, 0.02067969, 0.02779514, 0.04551504, 0.03792619,
#          0.03976666, 0.01932715, 0.01725966, 0.02294811, 0.03643893],
#         [0.04464871, 0.06331303, 0.06304896, 0.10061329, 0.07051806,
#          0.05531058, 0.06907357, 0.0339514 , 0.07431967, 0.08583063],
#         [0.09220518, 0.05880734, 0.10171822, 0.08531476, 0.06025342,
#          0.06062406, 0.08927534, 0.08197305, 0.08355597, 0.07712646],
#         [0.01132557, 0.01673283, 0.00119207, 0.01134066, 0.01020677,
#          0.01051101, 0.01447341, 0.04289672, 0.04768539, 0.02183508],
#         [0.23150373, 0.23251305, 0.2386813 , 0.28489797, 0.20398572,
#          0.22588963, 0.28164085, 0.21759432, 0.27090865, 0.22421553]])}

# %% [markdown]
# * feature별 Score 분포

# %%
plt.style.use(['dark_background'])
plt.figure(figsize = (10,8))
for i,vars in enumerate(list(x)) :
    sns.kdeplot(pfi1.importances[i], label = vars)

plt.legend()
plt.show()

# %%
sorted_idx = pfi1.importances_mean.argsort()
plt.figure(figsize = (10, 8))
plt.boxplot(pfi1.importances[sorted_idx].T, vert=False, labels=x.columns[sorted_idx])
plt.axvline(0, color = 'r')
plt.grid()
plt.show()

# %% [markdown]
# * 평균값으로 변수중요도 그래프 그리기

# %%
result = plot_feature_importance(pfi1.importances_mean, list(x_train))

# %% [markdown]
# ### 2) DL 모델

# %% [markdown]
# * 간단한 DL 모델을 생성해 봅시다.

# %%
x_train_s.shape[1]
# Out:
# 13

# %%
nfeatures = x_train_s.shape[1]
clear_session()

model2 = Sequential([Dense(32, input_shape = [nfeatures,], activation = 'relu'),
                     Dense(8, activation = 'relu'),
                     Dense(1)
                     ])

model2.compile(optimizer = 'adam', loss = 'mse')
history = model2.fit(x_train_s, y_train, epochs = 200, validation_split = .2).history
# Out:
# Epoch 1/200
# 11/11 [==============================] - 0s 9ms/step - loss: 632.5665 - val_loss: 592.5816
# Epoch 2/200
# 11/11 [==============================] - 0s 2ms/step - loss: 617.5585 - val_loss: 580.6359
# Epoch 3/200
# 11/11 [==============================] - 0s 2ms/step - loss: 606.3436 - val_loss: 571.3820
# Epoch 4/200
# 11/11 [==============================] - 0s 4ms/step - loss: 597.4072 - val_loss: 563.0180
# Epoch 5/200
# 11/11 [==============================] - 0s 2ms/step - loss: 588.5231 - val_loss: 553.1570
# Epoch 6/200
# 11/11 [==============================] - 0s 2ms/step - loss: 577.5275 - val_loss: 540.7829
# Epoch 7/200
# 11/11 [==============================] - 0s 2ms/step - loss: 563.5118 - val_loss: 525.1487
# Epoch 8/200
# 11/11 [==============================] - 0s 2ms/step - loss: 546.5990 - val_loss: 506.7294
# Epoch 9/200
# 11/11 [==============================] - 0s 2ms/step - loss: 526.5264 - val_loss: 485.1942
# Epoch 10/200
# 11/11 [==============================] - 0s 2ms/step - loss: 503.4350 - val_loss: 460.6870
# Epoch 11/200
# 11/11 [==============================] - 0s 2ms/step - loss: 477.6671 - val_loss: 433.0505
# Epoch 12/200
# 11/11 [==============================] - 0s 2ms/step - loss: 447.9124 - val_loss: 402.3146
# Epoch 13/200
# 11/11 [==============================] - 0s 2ms/step - loss: 415.7181 - val_loss: 368.2311
# Epoch 14/200
# 11/11 [==============================] - 0s 2ms/step - loss: 379.2035 - val_loss: 331.7133
# Epoch 15/200
# 11/11 [==============================] - 0s 2ms/step - loss: 341.9555 - val_loss: 294.6911
# Epoch 16/200
# 11/11 [==============================] - 0s 2ms/step - loss: 304.2997 - val_loss: 258.6273
# Epoch 17/200
# 11/11 [==============================] - 0s 2ms/step - loss: 268.2810 - val_loss: 224.8706
# Epoch 18/200
# 11/11 [==============================] - 0s 2ms/step - loss: 234.9212 - val_loss: 194.7732
# Epoch 19/200
# 11/11 [==============================] - 0s 2ms/step - loss: 205.8232 - val_loss: 170.5679
# Epoch 20/200
# 11/11 [==============================] - 0s 2ms/step - loss: 183.0785 - val_loss: 150.6212
# Epoch 21/200
# 11/11 [==============================] - 0s 2ms/step - loss: 163.9995 - val_loss: 136.0609
# Epoch 22/200
# 11/11 [==============================] - 0s 2ms/step - loss: 150.5086 - val_loss: 126.8140
# Epoch 23/200
# 11/11 [==============================] - 0s 2ms/step - loss: 141.4329 - val_loss: 120.2758
# Epoch 24/200
# 11/11 [==============================] - 0s 2ms/step - loss: 134.9659 - val_loss: 115.8561
# Epoch 25/200
# 11/11 [==============================] - 0s 2ms/step - loss: 129.8983 - val_loss: 112.2052
# Epoch 26/200
# 11/11 [==============================] - 0s 2ms/step - loss: 125.5789 - val_loss: 109.0085
# Epoch 27/200
# 11/11 [==============================] - 0s 2ms/step - loss: 121.8498 - val_loss: 106.0751
# Epoch 28/200
# 11/11 [==============================] - 0s 2ms/step - loss: 118.3583 - val_loss: 103.0810
# Epoch 29/200
# 11/11 [==============================] - 0s 2ms/step - loss: 115.1957 - val_loss: 100.1775
# Epoch 30/200
# 11/11 [==============================] - 0s 2ms/step - loss: 111.6454 - val_loss: 97.4291
# Epoch 31/200
# 11/11 [==============================] - 0s 2ms/step - loss: 108.3289 - val_loss: 94.8974
# Epoch 32/200
# 11/11 [==============================] - 0s 2ms/step - loss: 105.2629 - val_loss: 92.7896
# Epoch 33/200
# 11/11 [==============================] - 0s 2ms/step - loss: 102.0918 - val_loss: 90.0194
# Epoch 34/200
# 11/11 [==============================] - 0s 2ms/step - loss: 98.9307 - val_loss: 87.2691
# Epoch 35/200
# 11/11 [==============================] - 0s 2ms/step - loss: 95.5796 - val_loss: 84.6979
# Epoch 36/200
# 11/11 [==============================] - 0s 2ms/step - loss: 92.5273 - val_loss: 81.8615
# Epoch 37/200
# 11/11 [==============================] - 0s 2ms/step - loss: 89.5250 - val_loss: 78.9704
# Epoch 38/200
# 11/11 [==============================] - 0s 2ms/step - loss: 86.6986 - val_loss: 76.4250
# Epoch 39/200
# 11/11 [==============================] - 0s 2ms/step - loss: 84.0006 - val_loss: 74.2302
# Epoch 40/200
# 11/11 [==============================] - 0s 2ms/step - loss: 81.5378 - val_loss: 72.0137
# Epoch 41/200
# 11/11 [==============================] - 0s 2ms/step - loss: 78.9007 - val_loss: 70.0436
# Epoch 42/200
# 11/11 [==============================] - 0s 2ms/step - loss: 76.4861 - val_loss: 68.1314
# Epoch 43/200
# 11/11 [==============================] - 0s 2ms/step - loss: 74.1648 - val_loss: 65.9472
# Epoch 44/200
# 11/11 [==============================] - 0s 2ms/step - loss: 72.0404 - val_loss: 64.2863
# Epoch 45/200
# 11/11 [==============================] - 0s 2ms/step - loss: 69.9623 - val_loss: 62.7080
# Epoch 46/200
# 11/11 [==============================] - 0s 2ms/step - loss: 68.2703 - val_loss: 60.9334
# Epoch 47/200
# 11/11 [==============================] - 0s 2ms/step - loss: 66.4152 - val_loss: 59.7686
# Epoch 48/200
# 11/11 [==============================] - 0s 2ms/step - loss: 64.8313 - val_loss: 58.5991
# Epoch 49/200
# 11/11 [==============================] - 0s 2ms/step - loss: 63.2641 - val_loss: 57.8588
# Epoch 50/200
# 11/11 [==============================] - 0s 2ms/step - loss: 62.0566 - val_loss: 56.5773
# Epoch 51/200
# 11/11 [==============================] - 0s 2ms/step - loss: 60.7942 - val_loss: 55.4321
# Epoch 52/200
# 11/11 [==============================] - 0s 2ms/step - loss: 59.9200 - val_loss: 54.5282
# Epoch 53/200
# 11/11 [==============================] - 0s 2ms/step - loss: 58.9611 - val_loss: 53.9438
# Epoch 54/200
# 11/11 [==============================] - 0s 2ms/step - loss: 58.0550 - val_loss: 53.0508
# Epoch 55/200
# 11/11 [==============================] - 0s 2ms/step - loss: 57.2605 - val_loss: 52.0811
# Epoch 56/200
# 11/11 [==============================] - 0s 2ms/step - loss: 56.4792 - val_loss: 51.5147
# Epoch 57/200
# 11/11 [==============================] - 0s 2ms/step - loss: 55.7416 - val_loss: 51.1135
# Epoch 58/200
# 11/11 [==============================] - 0s 2ms/step - loss: 54.9866 - val_loss: 49.8925
# Epoch 59/200
# 11/11 [==============================] - 0s 2ms/step - loss: 54.3142 - val_loss: 49.5789
# Epoch 60/200
# 11/11 [==============================] - 0s 2ms/step - loss: 53.5113 - val_loss: 48.5047
# Epoch 61/200
# 11/11 [==============================] - 0s 2ms/step - loss: 52.9357 - val_loss: 48.2419
# Epoch 62/200
# 11/11 [==============================] - 0s 2ms/step - loss: 52.2419 - val_loss: 47.2893
# Epoch 63/200
# 11/11 [==============================] - 0s 2ms/step - loss: 51.7162 - val_loss: 46.5835
# Epoch 64/200
# 11/11 [==============================] - 0s 2ms/step - loss: 51.3396 - val_loss: 45.7602
# Epoch 65/200
# 11/11 [==============================] - 0s 2ms/step - loss: 50.6996 - val_loss: 45.5909
# Epoch 66/200
# 11/11 [==============================] - 0s 2ms/step - loss: 50.1468 - val_loss: 45.4325
# Epoch 67/200
# 11/11 [==============================] - 0s 2ms/step - loss: 49.7530 - val_loss: 44.6888
# Epoch 68/200
# 11/11 [==============================] - 0s 2ms/step - loss: 49.3117 - val_loss: 43.7998
# Epoch 69/200
# 11/11 [==============================] - 0s 2ms/step - loss: 48.9526 - val_loss: 43.1509
# Epoch 70/200
# 11/11 [==============================] - 0s 2ms/step - loss: 48.6197 - val_loss: 42.5114
# Epoch 71/200
# 11/11 [==============================] - 0s 2ms/step - loss: 47.8864 - val_loss: 42.5174
# Epoch 72/200
# 11/11 [==============================] - 0s 2ms/step - loss: 47.3531 - val_loss: 42.2186
# Epoch 73/200
# 11/11 [==============================] - 0s 2ms/step - loss: 46.8917 - val_loss: 41.4322
# Epoch 74/200
# 11/11 [==============================] - 0s 2ms/step - loss: 46.4054 - val_loss: 40.5619
# Epoch 75/200
# 11/11 [==============================] - 0s 2ms/step - loss: 45.9970 - val_loss: 40.0686
# Epoch 76/200
# 11/11 [==============================] - 0s 2ms/step - loss: 45.6711 - val_loss: 39.1888
# Epoch 77/200
# 11/11 [==============================] - 0s 2ms/step - loss: 45.2103 - val_loss: 38.8441
# Epoch 78/200
# 11/11 [==============================] - 0s 2ms/step - loss: 44.5882 - val_loss: 38.5778
# Epoch 79/200
# 11/11 [==============================] - 0s 2ms/step - loss: 44.2794 - val_loss: 38.9283
# Epoch 80/200
# 11/11 [==============================] - 0s 3ms/step - loss: 43.7666 - val_loss: 38.2727
# Epoch 81/200
# 11/11 [==============================] - 0s 2ms/step - loss: 43.1365 - val_loss: 36.9017
# Epoch 82/200
# 11/11 [==============================] - 0s 2ms/step - loss: 42.8491 - val_loss: 36.4945
# Epoch 83/200
# 11/11 [==============================] - 0s 2ms/step - loss: 42.4161 - val_loss: 36.4060
# Epoch 84/200
# 11/11 [==============================] - 0s 2ms/step - loss: 41.9848 - val_loss: 36.3046
# Epoch 85/200
# 11/11 [==============================] - 0s 2ms/step - loss: 41.9274 - val_loss: 36.3171
# Epoch 86/200
# 11/11 [==============================] - 0s 2ms/step - loss: 41.1994 - val_loss: 35.0503
# Epoch 87/200
# 11/11 [==============================] - 0s 2ms/step - loss: 40.9900 - val_loss: 34.1241
# Epoch 88/200
# 11/11 [==============================] - 0s 2ms/step - loss: 40.4638 - val_loss: 33.8203
# Epoch 89/200
# 11/11 [==============================] - 0s 2ms/step - loss: 39.9971 - val_loss: 33.6833
# Epoch 90/200
# 11/11 [==============================] - 0s 2ms/step - loss: 39.6442 - val_loss: 33.3724
# Epoch 91/200
# 11/11 [==============================] - 0s 2ms/step - loss: 39.2066 - val_loss: 32.9006
# Epoch 92/200
# 11/11 [==============================] - 0s 2ms/step - loss: 38.8416 - val_loss: 32.2666
# Epoch 93/200
# 11/11 [==============================] - 0s 2ms/step - loss: 38.5380 - val_loss: 31.7713
# Epoch 94/200
# 11/11 [==============================] - 0s 2ms/step - loss: 38.1676 - val_loss: 31.8658
# Epoch 95/200
# 11/11 [==============================] - 0s 2ms/step - loss: 37.7427 - val_loss: 30.9809
# Epoch 96/200
# 11/11 [==============================] - 0s 2ms/step - loss: 37.5647 - val_loss: 30.3562
# Epoch 97/200
# 11/11 [==============================] - 0s 2ms/step - loss: 37.2194 - val_loss: 30.0385
# Epoch 98/200
# 11/11 [==============================] - 0s 2ms/step - loss: 36.6214 - val_loss: 29.8042
# Epoch 99/200
# 11/11 [==============================] - 0s 2ms/step - loss: 36.3572 - val_loss: 29.3533
# Epoch 100/200
# 11/11 [==============================] - 0s 2ms/step - loss: 36.1199 - val_loss: 29.3532
# Epoch 101/200
# 11/11 [==============================] - 0s 2ms/step - loss: 35.6448 - val_loss: 28.4362
# Epoch 102/200
# 11/11 [==============================] - 0s 2ms/step - loss: 35.2385 - val_loss: 27.9618
# Epoch 103/200
# 11/11 [==============================] - 0s 2ms/step - loss: 34.9461 - val_loss: 27.6121
# Epoch 104/200
# 11/11 [==============================] - 0s 2ms/step - loss: 34.7419 - val_loss: 27.5985
# Epoch 105/200
# 11/11 [==============================] - 0s 2ms/step - loss: 34.2403 - val_loss: 27.2402
# Epoch 106/200
# 11/11 [==============================] - 0s 2ms/step - loss: 33.9013 - val_loss: 26.9575
# Epoch 107/200
# 11/11 [==============================] - 0s 2ms/step - loss: 33.6594 - val_loss: 26.8883
# Epoch 108/200
# 11/11 [==============================] - 0s 2ms/step - loss: 33.3132 - val_loss: 26.5022
# Epoch 109/200
# 11/11 [==============================] - 0s 2ms/step - loss: 33.0694 - val_loss: 26.7264
# Epoch 110/200
# 11/11 [==============================] - 0s 2ms/step - loss: 32.8509 - val_loss: 25.9271
# Epoch 111/200
# 11/11 [==============================] - 0s 2ms/step - loss: 32.2149 - val_loss: 25.0357
# Epoch 112/200
# 11/11 [==============================] - 0s 2ms/step - loss: 31.9461 - val_loss: 24.6473
# Epoch 113/200
# 11/11 [==============================] - 0s 2ms/step - loss: 31.6374 - val_loss: 24.3662
# Epoch 114/200
# 11/11 [==============================] - 0s 2ms/step - loss: 31.3858 - val_loss: 23.8703
# Epoch 115/200
# 11/11 [==============================] - 0s 2ms/step - loss: 31.1208 - val_loss: 23.5019
# Epoch 116/200
# 11/11 [==============================] - 0s 2ms/step - loss: 31.0024 - val_loss: 23.2197
# Epoch 117/200
# 11/11 [==============================] - 0s 2ms/step - loss: 30.7846 - val_loss: 23.1168
# Epoch 118/200
# 11/11 [==============================] - 0s 2ms/step - loss: 30.5334 - val_loss: 23.0682
# Epoch 119/200
# 11/11 [==============================] - 0s 3ms/step - loss: 30.4022 - val_loss: 22.4845
# Epoch 120/200
# 11/11 [==============================] - 0s 2ms/step - loss: 30.0105 - val_loss: 23.3216
# Epoch 121/200
# 11/11 [==============================] - 0s 2ms/step - loss: 29.8518 - val_loss: 22.3460
# Epoch 122/200
# 11/11 [==============================] - 0s 2ms/step - loss: 29.3547 - val_loss: 21.8129
# Epoch 123/200
# 11/11 [==============================] - 0s 2ms/step - loss: 29.1202 - val_loss: 21.6199
# Epoch 124/200
# 11/11 [==============================] - 0s 2ms/step - loss: 29.0131 - val_loss: 21.5970
# Epoch 125/200
# 11/11 [==============================] - 0s 2ms/step - loss: 28.5793 - val_loss: 21.1101
# Epoch 126/200
# 11/11 [==============================] - 0s 2ms/step - loss: 28.4144 - val_loss: 20.8734
# Epoch 127/200
# 11/11 [==============================] - 0s 2ms/step - loss: 28.2892 - val_loss: 20.5492
# Epoch 128/200
# 11/11 [==============================] - 0s 2ms/step - loss: 28.1049 - val_loss: 20.5962
# Epoch 129/200
# 11/11 [==============================] - 0s 2ms/step - loss: 27.8322 - val_loss: 20.1935
# Epoch 130/200
# 11/11 [==============================] - 0s 2ms/step - loss: 27.5883 - val_loss: 19.9182
# Epoch 131/200
# 11/11 [==============================] - 0s 2ms/step - loss: 27.3846 - val_loss: 19.8317
# Epoch 132/200
# 11/11 [==============================] - 0s 2ms/step - loss: 27.1584 - val_loss: 19.7415
# Epoch 133/200
# 11/11 [==============================] - 0s 2ms/step - loss: 27.0647 - val_loss: 19.7703
# Epoch 134/200
# 11/11 [==============================] - 0s 2ms/step - loss: 26.7648 - val_loss: 19.2824
# Epoch 135/200
# 11/11 [==============================] - 0s 2ms/step - loss: 26.6115 - val_loss: 19.1222
# Epoch 136/200
# 11/11 [==============================] - 0s 2ms/step - loss: 26.4776 - val_loss: 19.0432
# Epoch 137/200
# 11/11 [==============================] - 0s 2ms/step - loss: 26.2800 - val_loss: 18.8231
# Epoch 138/200
# 11/11 [==============================] - 0s 2ms/step - loss: 26.2070 - val_loss: 18.8423
# Epoch 139/200
# 11/11 [==============================] - 0s 2ms/step - loss: 25.9666 - val_loss: 18.5618
# Epoch 140/200
# 11/11 [==============================] - 0s 2ms/step - loss: 26.0020 - val_loss: 18.3130
# Epoch 141/200
# 11/11 [==============================] - 0s 2ms/step - loss: 25.7405 - val_loss: 18.2402
# Epoch 142/200
# 11/11 [==============================] - 0s 2ms/step - loss: 25.5253 - val_loss: 18.2013
# Epoch 143/200
# 11/11 [==============================] - 0s 2ms/step - loss: 25.3381 - val_loss: 17.9790
# Epoch 144/200
# 11/11 [==============================] - 0s 2ms/step - loss: 25.2837 - val_loss: 17.9712
# Epoch 145/200
# 11/11 [==============================] - 0s 2ms/step - loss: 25.1346 - val_loss: 17.9114
# Epoch 146/200
# 11/11 [==============================] - 0s 2ms/step - loss: 24.8832 - val_loss: 17.6252
# Epoch 147/200
# 11/11 [==============================] - 0s 2ms/step - loss: 24.9387 - val_loss: 17.6097
# Epoch 148/200
# 11/11 [==============================] - 0s 2ms/step - loss: 24.6970 - val_loss: 17.3808
# Epoch 149/200
# 11/11 [==============================] - 0s 2ms/step - loss: 24.6586 - val_loss: 17.3122
# Epoch 150/200
# 11/11 [==============================] - 0s 2ms/step - loss: 24.4951 - val_loss: 17.3249
# Epoch 151/200
# 11/11 [==============================] - 0s 2ms/step - loss: 24.4168 - val_loss: 17.3732
# Epoch 152/200
# 11/11 [==============================] - 0s 2ms/step - loss: 24.2777 - val_loss: 17.1675
# Epoch 153/200
# 11/11 [==============================] - 0s 2ms/step - loss: 24.1336 - val_loss: 16.9753
# Epoch 154/200
# 11/11 [==============================] - 0s 2ms/step - loss: 24.0290 - val_loss: 16.8605
# Epoch 155/200
# 11/11 [==============================] - 0s 2ms/step - loss: 23.8962 - val_loss: 16.9381
# Epoch 156/200
# 11/11 [==============================] - 0s 2ms/step - loss: 24.0587 - val_loss: 16.9924
# Epoch 157/200
# 11/11 [==============================] - 0s 2ms/step - loss: 23.6303 - val_loss: 16.5535
# Epoch 158/200
# 11/11 [==============================] - 0s 2ms/step - loss: 23.6717 - val_loss: 16.5268
# Epoch 159/200
# 11/11 [==============================] - 0s 2ms/step - loss: 23.3864 - val_loss: 16.3883
# Epoch 160/200
# 11/11 [==============================] - 0s 2ms/step - loss: 23.4638 - val_loss: 16.3124
# Epoch 161/200
# 11/11 [==============================] - 0s 2ms/step - loss: 23.3841 - val_loss: 16.2460
# Epoch 162/200
# 11/11 [==============================] - 0s 2ms/step - loss: 23.4952 - val_loss: 16.2262
# Epoch 163/200
# 11/11 [==============================] - 0s 3ms/step - loss: 23.1281 - val_loss: 16.2254
# Epoch 164/200
# 11/11 [==============================] - 0s 2ms/step - loss: 23.3063 - val_loss: 16.3026
# Epoch 165/200
# 11/11 [==============================] - 0s 2ms/step - loss: 23.1296 - val_loss: 16.0240
# Epoch 166/200
# 11/11 [==============================] - 0s 2ms/step - loss: 22.9191 - val_loss: 16.5073
# Epoch 167/200
# 11/11 [==============================] - 0s 2ms/step - loss: 23.0756 - val_loss: 16.1394
# Epoch 168/200
# 11/11 [==============================] - 0s 2ms/step - loss: 22.8052 - val_loss: 15.9708
# Epoch 169/200
# 11/11 [==============================] - 0s 2ms/step - loss: 22.7567 - val_loss: 15.9388
# Epoch 170/200
# 11/11 [==============================] - 0s 2ms/step - loss: 22.8846 - val_loss: 16.2585
# Epoch 171/200
# 11/11 [==============================] - 0s 2ms/step - loss: 22.7650 - val_loss: 15.9658
# Epoch 172/200
# 11/11 [==============================] - 0s 2ms/step - loss: 22.5700 - val_loss: 15.7924
# Epoch 173/200
# 11/11 [==============================] - 0s 2ms/step - loss: 22.3985 - val_loss: 15.7709
# Epoch 174/200
# 11/11 [==============================] - 0s 2ms/step - loss: 22.3804 - val_loss: 15.7558
# Epoch 175/200
# 11/11 [==============================] - 0s 2ms/step - loss: 22.2666 - val_loss: 15.6775
# Epoch 176/200
# 11/11 [==============================] - 0s 2ms/step - loss: 22.2168 - val_loss: 15.6162
# Epoch 177/200
# 11/11 [==============================] - 0s 2ms/step - loss: 22.1757 - val_loss: 15.5734
# Epoch 178/200
# 11/11 [==============================] - 0s 2ms/step - loss: 22.1427 - val_loss: 15.5254
# Epoch 179/200
# 11/11 [==============================] - 0s 2ms/step - loss: 22.5317 - val_loss: 16.5415
# Epoch 180/200
# 11/11 [==============================] - 0s 2ms/step - loss: 22.4973 - val_loss: 15.6177
# Epoch 181/200
# 11/11 [==============================] - 0s 2ms/step - loss: 22.0085 - val_loss: 15.5297
# Epoch 182/200
# 11/11 [==============================] - 0s 2ms/step - loss: 21.9055 - val_loss: 15.5003
# Epoch 183/200
# 11/11 [==============================] - 0s 2ms/step - loss: 21.8592 - val_loss: 15.5612
# Epoch 184/200
# 11/11 [==============================] - 0s 2ms/step - loss: 21.7696 - val_loss: 15.4852
# Epoch 185/200
# 11/11 [==============================] - 0s 2ms/step - loss: 21.7610 - val_loss: 15.4637
# Epoch 186/200
# 11/11 [==============================] - 0s 2ms/step - loss: 21.7063 - val_loss: 15.4360
# Epoch 187/200
# 11/11 [==============================] - 0s 4ms/step - loss: 21.7140 - val_loss: 15.3518
# Epoch 188/200
# 11/11 [==============================] - 0s 2ms/step - loss: 21.6932 - val_loss: 15.3834
# Epoch 189/200
# 11/11 [==============================] - 0s 2ms/step - loss: 21.6351 - val_loss: 15.3327
# Epoch 190/200
# 11/11 [==============================] - 0s 2ms/step - loss: 21.4890 - val_loss: 15.3174
# Epoch 191/200
# 11/11 [==============================] - 0s 2ms/step - loss: 21.5099 - val_loss: 15.3157
# Epoch 192/200
# 11/11 [==============================] - 0s 2ms/step - loss: 21.6431 - val_loss: 15.3054
# Epoch 193/200
# 11/11 [==============================] - 0s 2ms/step - loss: 21.4896 - val_loss: 16.0436
# Epoch 194/200
# 11/11 [==============================] - 0s 2ms/step - loss: 22.0375 - val_loss: 15.6265
# Epoch 195/200
# 11/11 [==============================] - 0s 2ms/step - loss: 21.2799 - val_loss: 15.5278
# Epoch 196/200
# 11/11 [==============================] - 0s 2ms/step - loss: 21.6737 - val_loss: 15.5849
# Epoch 197/200
# 11/11 [==============================] - 0s 2ms/step - loss: 21.2240 - val_loss: 15.2597
# Epoch 198/200
# 11/11 [==============================] - 0s 2ms/step - loss: 21.1827 - val_loss: 15.2429
# Epoch 199/200
# 11/11 [==============================] - 0s 2ms/step - loss: 21.2147 - val_loss: 15.2335
# Epoch 200/200
# 11/11 [==============================] - 0s 2ms/step - loss: 21.1330 - val_loss: 15.2096

# %% [markdown]
# * permutation feature importance 구하기
#     * deep learning 모델에 대해서는 명시적으로 scoring = 'r2'을 지정해 줘야 합니다.

# %%
pfi2 = permutation_importance(model2, x_val_s, y_val, n_repeats=10, scoring = 'r2', random_state=2022)

# %%
pfi2
# Out:
# {'importances_mean': array([0.02902828, 0.01618357, 0.01151953, 0.00882522, 0.02271248,
#         0.20013056, 0.00386116, 0.02952838, 0.08211316, 0.0670694 ,
#         0.05490154, 0.05747942, 0.52799006]),
#  'importances_std': array([0.01117577, 0.01081695, 0.00444008, 0.00749513, 0.00586642,
#         0.03548657, 0.00963001, 0.02078138, 0.03012575, 0.01680402,
#         0.01349282, 0.01534794, 0.06861408]),
#  'importances': array([[ 0.03260333,  0.03419596,  0.03895605,  0.03839521,  0.01048868,
#           0.0302938 ,  0.04678447,  0.01782021,  0.02697279,  0.0137723 ],
#         [ 0.010587  ,  0.01438112,  0.00730322,  0.03277571,  0.02549867,
#           0.01585226,  0.02874386, -0.00393191,  0.00723377,  0.02339197],
#         [ 0.00748363,  0.01434283,  0.01112924,  0.00456668,  0.00922963,
#           0.01803587,  0.01905244,  0.00713383,  0.01206045,  0.0121607 ],
#         [ 0.01240703,  0.01240277, -0.00708027,  0.0213528 ,  0.01205271,
#           0.01032024,  0.0029063 ,  0.00166317,  0.00821878,  0.01400866],
#         [ 0.01758775,  0.02501073,  0.01634893,  0.02657353,  0.02314622,
#           0.02401334,  0.03129365,  0.0121881 ,  0.03075333,  0.02020924],
#         [ 0.20975005,  0.21153502,  0.13539677,  0.16086884,  0.22119143,
#           0.23760441,  0.23622225,  0.15375171,  0.19833417,  0.23665099],
#         [ 0.01156185,  0.00465747,  0.01709547, -0.00543549, -0.00137318,
#           0.00668332, -0.01405705,  0.0176217 , -0.00370195,  0.00555948],
#         [ 0.02425406,  0.01875796,  0.06480448,  0.0358988 ,  0.04673661,
#           0.0110091 , -0.0048367 ,  0.05906106,  0.01776021,  0.02183827],
#         [ 0.07334439,  0.08604385,  0.06743855,  0.07037616,  0.10583587,
#           0.09923455,  0.04835298,  0.1207927 ,  0.02469117,  0.12502134],
#         [ 0.05832347,  0.07080395,  0.06555183,  0.08995289,  0.05108335,
#           0.06390593,  0.08775136,  0.03066368,  0.0792616 ,  0.07339597],
#         [ 0.0545503 ,  0.02800606,  0.04858133,  0.06178537,  0.0528897 ,
#           0.05116251,  0.0691007 ,  0.04571756,  0.08145333,  0.05576856],
#         [ 0.05381419,  0.03709441,  0.04035496,  0.06818669,  0.05721619,
#           0.04763236,  0.04677592,  0.0904567 ,  0.07173542,  0.06152731],
#         [ 0.49481239,  0.46896532,  0.54916535,  0.59712121,  0.48986063,
#           0.46493563,  0.62525997,  0.44496154,  0.64835571,  0.49646285]])}

# %% [markdown]
# * feature별 Score 분포

# %%
plt.figure(figsize = (12,8))
for i,vars in enumerate(list(x)) :
    sns.kdeplot(pfi2.importances[i], label = vars)

plt.legend()
plt.show()

# %%
sorted_idx = pfi2.importances_mean.argsort()
plt.figure(figsize = (12,8))
plt.boxplot(pfi2.importances[sorted_idx].T, vert=False, labels=x.columns[sorted_idx])
plt.axvline(0, color = 'r')
plt.grid()
plt.show()

# %% [markdown]
# * 평균값으로 변수중요도 그래프 그리기

# %%
result = plot_feature_importance(pfi2.importances_mean, list(x_train))

# %%
from sklearn.metrics import *

# %%
pred1 = model1.predict(x_val_s)
print(mean_absolute_error(y_val, pred1))
# Out:
# 3.246841982884418

# %%
pred2 = model2.predict(x_val_s)
print(mean_absolute_error(y_val, pred2))
# Out:
# 3.919317752707238

# %% [markdown]
# ## 4.실습 : 직원 이직 예측모델 변수 중요도 비교

# %% [markdown]
# ### 1) 데이터 준비

# %% [markdown]
# * 데이터 로딩

# %%
# data data
path = "https://raw.githubusercontent.com/DA4BAM/dataset/master/Attrition2.csv"
data = pd.read_csv(path)
data.head(10)
# Out:
#    Attrition  Age              Department  DistanceFromHome  Education  \
# 0          0   28  Research & Development                 1          3
# 1          1   37  Research & Development                 2          2
# 2          0   27  Research & Development                 8          5
# 3          0   18  Research & Development                 1          3
# 4          0   29  Research & Development                 9          3
# 5          0   44  Research & Development                 2          1
# 6          0   41                   Sales                10          2
# 7          0   25                   Sales                18          1
# 8          0   50  Research & Development                 2          3
# 9          0   47                   Sales                 4          2
#
#   EducationField  Gender                 JobRole  JobSatisfaction  \
# 0        Medical  Female      Research Scientist                1
# 1          Other    Male   Laboratory Technician                3
# 2  Life Sciences    Male   Laboratory Technician                3
# 3  Life Sciences  Female   Laboratory Technician                4
# 4  Life Sciences    Male      Research Scientist                3
# 5        Medical    Male  Manufacturing Director                3
# 6  Life Sciences    Male         Sales Executive                4
# 7  Life Sciences    Male         Sales Executive                3
# 8        Medical    Male       Research Director                3
# 9  Life Sciences  Female         Sales Executive                4
#
#   MaritalStatus  MonthlyIncome  NumCompaniesWorked  RelationshipSatisfaction  \
# 0       Married           3591                   1                         3
# 1        Single           2090                   6                         2
# 2       Married           4621                   1                         4
# 3        Single           1611                   1                         3
# 4       Married           2451                   6                         1
# 5        Single          10209                   5                         2
# 6        Single           6230                   7                         4
# 7       Married           6232                   2                         2
# 8       Married          17639                   5                         4
# 9        Single           4163                   1                         3
#
#    TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany
# 0                  3                      3                3               3
# 1                  7                      3                3               0
# 2                  3                      4                3               3
# 3                  0                      5                4               0
# 4                  5                      2                2               1
# 5                 16                      2                2               2
# 6                 16                      3                3              14
# 7                  6                      3                2               3
# 8                 30                      3                3               4
# 9                  9                      0                3               9

# %% [markdown]
# |	변수 명	|	내용	|	구분	|
# |	----	|	----	|	----	|
# |	**Attrition**	|	이직여부, Yes = 1 , No = 0	|	**Target**	|
# |	Age	|	나이	|	숫자	|
# |	BusinessTravel	|	출장 빈도(범주)	|		|
# |	Department	|	현 부서	|		|
# |	DistanceFromHome	|	집-직장 거리(마일)	|	숫자	|
# |	Education	|	교육수준(범주)	|	1 Below College, 2 College, 3 Bachelor, 4 Master, 5 Doctor	|
# |	EducationField	|	전공	|		|
# |	EnvironmentSatisfaction	|	근무환경에 대한 만족도(범주)	|	1 Low, 2 Good, 3 Excellent, 4 Outstanding	|
# |	Gender	|	성별	|		|
# |	JobInvolvement	|	직무 적극성(참여도)	|	1 Low, 2 Medium, 3 High, 4 Very High	|
# |	JobRole	|	직무	|		|
# |	JobSatisfaction	|	직무 만족도	|	1 Low, 2 Medium, 3 High, 4 Very High	|
# |	MaritalStatus	|	결혼상태	|		|
# |	MonthlyIncome	|	월급	|	숫자	|
# |	NumCompaniesWorked	|	현재까지 근무한 회사 수	|	숫자	|
# |	PercentSalaryHike	|	전년대비 급여인상율(%)	|	숫자	|
# |	RelationshipSatisfaction	|	동료와의 관계 만족도	|	1 Low, 2 Medium, 3 High, 4 Very High	|
# |	StockOptionLevel	|	스톡옵션 수준 0~3	|	범주	|
# |	TotalWorkingYears	|	총 근무 연수	|	숫자	|
# |	TrainingTimesLastYear	|	전년 교육훈련 횟수	|	숫자	|
# |	WorkLifeBalance	|	워라밸. 일-삶 균형도	|	1 Bad, 2 Good, 3 Better, 4 Best	|
# |	YearsAtCompany	|	현직장 근무 연수	|	숫자	|
# |	YearsInCurrentRole	|	현직무 연수	|	숫자	|
# |	YearsWithCurrManager	|	현 팀장과 근무한 연수	|	숫자	|

# %%
target = 'Attrition'
x = data.drop(target, axis = 1)
y = data.loc[:, target]

# %%
y.value_counts() / y.shape[0]
# Out:
# 0    0.913043
# 1    0.086957
# Name: Attrition, dtype: float64

# %% [markdown]
# * 가변수화 Dummy Variable

# %%
dummy_vars = ['Education','Department','EducationField','Gender','JobRole','JobSatisfaction','MaritalStatus',
              'RelationshipSatisfaction','WorkLifeBalance'] # 가변수화 대상 변수 이름 리스트 만든다
x = pd.get_dummies(x, columns = dummy_vars, drop_first=True)

# %% [markdown]
# * 데이터 분할
#     * 이미 test set은 분할되어 있다고 가정합니다.
#     * 주어진 데이터를 train set : validation set 으로 분할

# %%
# train_val에서 train : val = 8 : 2
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=0.2, random_state = 2022)

# %%
print(x_train.shape, x_val.shape)
# Out:
# (920, 38) (230, 38)

# %% [markdown]
# * class balance를 맞추기 위한 resampling

# %%
from imblearn.over_sampling import SMOTE

# %%
smote = SMOTE()
sm_x_train, sm_y_train = smote.fit_resample(x_train, y_train)

# %% [markdown]
# * 스케일링

# %%
scaler = MinMaxScaler()
sm_x_train_s = scaler.fit_transform(sm_x_train)
x_val_s = scaler.transform(x_val)

# %% [markdown]
# ### 2) 모델링 및 변수 중요도 계산하기
#
# * model1 : SVM
# * model2 : KNN

# %%
from sklearn.inspection import permutation_importance

# %% [markdown]
# #### ① SVM 모델

# %% [markdown]
# * 모델링

# %%
model_svm = SVC().fit(sm_x_train_s,sm_y_train)

# %% [markdown]
# * permutation feature importance 구하기

# %%
temp = permutation_importance(model_svm, sm_x_train_s, sm_y_train, n_repeats=10, scoring='r2')

# %%
temp.importances_mean
# Out:
# array([ 0.00072029,  0.00504202,  0.0057623 ,  0.00432173,  0.00216086,
#         0.0057623 ,  0.00072029,  0.0057623 ,  0.0060024 ,  0.00744298,
#         0.00072029,  0.00072029,  0.0062425 ,  0.05498199,  0.00432173,
#         0.05330132, -0.00096038, -0.00360144,  0.00696279,  0.00936375,
#         0.00720288,  0.00504202,  0.00048019,  0.        ,  0.00480192,
#         0.00168067,  0.00696279,  0.00912365,  0.00432173,  0.01008403,
#         0.0244898 ,  0.00984394,  0.0062425 ,  0.02040816,  0.00960384,
#         0.02521008,  0.03457383,  0.00504202])

# %% [markdown]
# * feature별 Score 분포

# %%
plt.figure(figsize = (12,8))
for i, vars in enumerate(list(x)) :
    sns.kdeplot(temp.importances[i], label = vars)

plt.legend()
plt.show()

# %% [markdown]
# * 평균값으로 변수중요도 그래프 그리기

# %%
sorted_svm = temp.importances_mean.argsort()
plt.figure(figsize = (12,8))
plt.boxplot(temp.importances[sorted_svm].T, vert=False, labels=x.columns[sorted_svm])
plt.axvline(0, color = 'r')
plt.grid()
plt.show()

# %% [markdown]
# * 예측 및 평가

# %% [markdown]
# #### ② KNN 모델

# %% [markdown]
# * 모델링

# %%
model_knn = KNeighborsClassifier().fit(sm_x_train_s, sm_y_train)

# %% [markdown]
# * permutation feature importance 구하기

# %%
pfi_knn = permutation_importance(model_knn, sm_x_train_s, sm_y_train, n_repeats=10)

# %% [markdown]
# * feature별 Score 분포

# %%
plt.figure(figsize=(12,8))
for i, var in enumerate(list(x)):
    sns.kdeplot(x=pfi_knn.importances[i], label=var)
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# * 평균값으로 변수중요도 그래프 그리기

# %%
sorted_knn_idx = pfi_knn.importances_mean.argsort()

# %%
plt.figure(figsize = (12,8))
plt.boxplot(pfi_knn.importances[sorted_knn_idx].T, vert=False, labels=x.columns[sorted_knn_idx])
plt.axvline(0, color = 'r')
plt.grid()
plt.show()

# %%
pfi_knn.importances
# Out:
# array([[ 0.        ,  0.00540216,  0.00360144,  0.00060024,  0.00360144,
#          0.00660264,  0.0030012 ,  0.0030012 ,  0.00420168, -0.00060024],
#        [-0.00180072,  0.        , -0.0030012 ,  0.00240096,  0.00420168,
#          0.00360144, -0.00120048,  0.00360144,  0.        , -0.00180072],
#        [ 0.00240096,  0.00180072, -0.00120048,  0.0030012 ,  0.00120048,
#          0.0030012 ,  0.00120048,  0.00180072,  0.00120048, -0.00180072],
#        [ 0.00120048,  0.00060024,  0.        ,  0.        , -0.00240096,
#         -0.00060024, -0.00240096,  0.00120048, -0.0030012 , -0.00060024],
#        [ 0.00240096,  0.00120048,  0.00360144,  0.00240096,  0.00120048,
#          0.00360144,  0.00060024,  0.00420168,  0.00480192,  0.00240096],
#        [ 0.00360144,  0.00240096,  0.00180072,  0.00060024,  0.00060024,
#         -0.00060024,  0.00060024,  0.00060024,  0.00120048,  0.0030012 ],
#        [ 0.        ,  0.00180072,  0.00120048,  0.00120048,  0.00060024,
#          0.00180072,  0.00060024,  0.00060024,  0.00120048,  0.00120048],
#        [ 0.00660264,  0.00480192,  0.01020408,  0.00840336,  0.01080432,
#          0.00420168,  0.00840336,  0.00780312,  0.00780312,  0.00840336],
#        [ 0.00540216,  0.00780312,  0.01560624,  0.00780312,  0.0120048 ,
#          0.00720288,  0.01380552,  0.0030012 ,  0.01260504,  0.00720288],
#        [ 0.01380552,  0.01560624,  0.0120048 ,  0.0120048 ,  0.01740696,
#          0.01380552,  0.01260504,  0.01440576,  0.01980792,  0.01740696],
#        [ 0.00060024,  0.00120048,  0.        ,  0.00060024,  0.00060024,
#          0.        ,  0.00060024,  0.00060024,  0.00060024,  0.00060024],
#        [ 0.03721489,  0.04321729,  0.04501801,  0.0270108 ,  0.04621849,
#          0.03961585,  0.03661465,  0.03541417,  0.03901561,  0.03901561],
#        [ 0.0120048 ,  0.00960384,  0.01020408,  0.01440576,  0.01260504,
#          0.01140456,  0.01080432,  0.0090036 ,  0.01440576,  0.01260504],
#        [ 0.02521008,  0.02460984,  0.02941176,  0.03181273,  0.02821128,
#          0.02641056,  0.02460984,  0.03601441,  0.03721489,  0.02521008],
#        [ 0.00660264,  0.00540216,  0.00540216,  0.00720288,  0.0060024 ,
#          0.00780312,  0.00720288,  0.00720288,  0.0060024 ,  0.00660264],
#        [ 0.01860744,  0.02460984,  0.02160864,  0.02160864,  0.0210084 ,
#          0.02280912,  0.02040816,  0.02521008,  0.02040816,  0.02160864],
#        [ 0.00360144,  0.00420168,  0.0030012 ,  0.00180072,  0.0030012 ,
#          0.0030012 ,  0.00240096,  0.00180072,  0.00240096,  0.0030012 ],
#        [ 0.00720288,  0.00780312,  0.00660264,  0.00660264,  0.00660264,
#          0.00720288,  0.00660264,  0.00720288,  0.00780312,  0.00720288],
#        [ 0.01080432,  0.00360144, -0.00120048,  0.0060024 ,  0.00420168,
#          0.00780312,  0.0060024 ,  0.00660264,  0.0060024 ,  0.00360144],
#        [ 0.0030012 ,  0.00360144,  0.0030012 ,  0.00360144,  0.00360144,
#          0.00360144,  0.00360144,  0.00360144,  0.0030012 ,  0.0030012 ],
#        [ 0.00480192,  0.00540216,  0.00480192,  0.00420168,  0.0030012 ,
#          0.00360144,  0.00120048,  0.00480192,  0.00660264,  0.00240096],
#        [ 0.00360144,  0.00420168,  0.0030012 ,  0.00420168,  0.00420168,
#          0.00480192,  0.00420168,  0.00360144,  0.00360144,  0.00480192],
#        [ 0.0060024 ,  0.00660264,  0.0060024 ,  0.0060024 ,  0.00720288,
#          0.00660264,  0.0060024 ,  0.00660264,  0.00660264,  0.00660264],
#        [ 0.00060024,  0.00120048,  0.00060024,  0.00060024,  0.00180072,
#          0.00120048,  0.00120048,  0.00120048,  0.00120048,  0.00120048],
#        [ 0.00180072,  0.0060024 ,  0.0060024 ,  0.0030012 ,  0.00480192,
#          0.00840336,  0.00420168,  0.00720288,  0.00360144,  0.00240096],
#        [ 0.00780312,  0.00660264,  0.00840336,  0.00960384,  0.00840336,
#          0.00840336,  0.00840336,  0.00840336,  0.00840336,  0.00780312],
#        [ 0.00240096,  0.00120048,  0.        ,  0.00120048,  0.00060024,
#          0.00180072,  0.00180072,  0.        ,  0.00120048,  0.00120048],
#        [ 0.01020408,  0.00660264,  0.00960384,  0.01320528,  0.01020408,
#          0.00960384,  0.0120048 ,  0.01140456,  0.01080432,  0.01020408],
#        [ 0.015006  ,  0.0120048 ,  0.00840336,  0.01260504,  0.01080432,
#          0.00540216,  0.0090036 ,  0.01080432,  0.00840336,  0.01440576],
#        [ 0.01080432,  0.015006  ,  0.01680672,  0.01320528,  0.01920768,
#          0.015006  ,  0.00960384,  0.01560624,  0.01320528,  0.01380552],
#        [ 0.00360144,  0.01020408,  0.00840336,  0.00660264,  0.00780312,
#          0.0090036 ,  0.01080432,  0.0090036 ,  0.00720288,  0.00840336],
#        [ 0.00360144,  0.0030012 ,  0.00360144,  0.00780312,  0.00420168,
#          0.0030012 ,  0.00360144,  0.00120048,  0.00120048,  0.00480192],
#        [ 0.00660264,  0.00540216,  0.00960384,  0.00720288,  0.00720288,
#          0.0060024 ,  0.00660264,  0.00480192,  0.0090036 ,  0.00660264],
#        [ 0.01620648,  0.00840336,  0.01020408,  0.01440576,  0.01380552,
#          0.01080432,  0.0120048 ,  0.015006  ,  0.01320528,  0.01020408],
#        [ 0.01080432,  0.01320528,  0.01320528,  0.01260504,  0.01740696,
#          0.0120048 ,  0.01320528,  0.00960384,  0.00840336,  0.01080432],
#        [ 0.015006  ,  0.01620648,  0.01560624,  0.01380552,  0.01620648,
#          0.01440576,  0.01680672,  0.01620648,  0.01920768,  0.0180072 ],
#        [ 0.02521008,  0.02821128,  0.02581032,  0.02040816,  0.03061224,
#          0.02941176,  0.03241297,  0.03061224,  0.02821128,  0.02521008],
#        [ 0.0060024 ,  0.00660264,  0.0060024 ,  0.0060024 ,  0.00480192,
#          0.0060024 ,  0.0060024 ,  0.0030012 ,  0.00780312,  0.0060024 ]])
